# %%
from sklearn.tree.export import export_text
import pandas as pd
import numpy as np
import mglearn as mglearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
import sys
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
import xlsxwriter
#import all the stuff
# Out:
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
data = pd.read_excel('/Users/jpjansen/Documents/Machine Learning Set V2.xlsx',header = 0)
data = data.dropna()
np.set_printoptions(threshold=sys.maxsize)
##read in data set

# %%
MachineLearning = data.to_numpy()

# %%
X = MachineLearning[:,2:18] #specify my matrix of features for the machine learning 
FortyOneUp= MachineLearning[:,-1]
ThirtyEightUp = MachineLearning[:,-2] 

ThirtyFiveUp = MachineLearning[:,-3]
ThirtyTwoUp = MachineLearning[:,-4]
TwentyNineUp = MachineLearning[:,-5]
TwentySixUp = MachineLearning[:,-6]
TwentyThreeUp = MachineLearning[:,-7]
TwentyUp = MachineLearning[:,-8]
SeventeenUp = MachineLearning[:,-9]
FourteenUp = MachineLearning[:,-10]
TwelveUp = MachineLearning[:,-11]
TenUp = MachineLearning[:,-12]
EightUp = MachineLearning[:,-13]
SixUp = MachineLearning[:,-14]
FourUp = MachineLearning[:,-15]
ThreeUp = MachineLearning[:,-16]
TwoUp = MachineLearning[:,-17]
OneUp = MachineLearning[:,-18]
OneDown= MachineLearning[:,-19]
TwoDown= MachineLearning[:,-20]
ThreeDown= MachineLearning[:,-21]
FourDown=MachineLearning[:,-22]
SixDown= MachineLearning[:,-23]
EightDown= MachineLearning[:,-24]
TenDown= MachineLearning[:,-25]
TwelveDown= MachineLearning[:,-26]
FourteenDown= MachineLearning[:,-27]
SeventeenDown= MachineLearning[:,-28]
TwentyDown= MachineLearning[:,-29]
TwentyThreeDown= MachineLearning[:,-30]
TwentySixDown= MachineLearning[:,-31]
TwentyNineDown= MachineLearning[:,-32]
ThirtyTwoDown= MachineLearning[:,-33]
ThirtyFiveDown= MachineLearning[:,-34]
ThirtyEightDown= MachineLearning[:,-35]
FortyOneDown= MachineLearning[:,-36]
print(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, OneUp,random_state=0)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
OneUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=0) 
OneUpforest.fit(X_train, y_train)
OneUpAccuracy = OneUpforest.score(X_test, y_test)
OneUpTrain = OneUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwoUp,random_state=1)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwoUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=1) 
TwoUpforest.fit(X_train, y_train)  
TwoUpAccuracy = TwoUpforest.score(X_test, y_test)
TwoUpTrain = TwoUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThreeUp,random_state=2)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThreeUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=2) 
ThreeUpforest.fit(X_train, y_train) 
ThreeUpAccuracy = ThreeUpforest.score(X_test, y_test)
ThreeUpTrain= ThreeUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FourUp,random_state=3)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FourUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=3) 
FourUpforest.fit(X_train, y_train) 
FourUpAccuracy = FourUpforest.score(X_test, y_test)
FourUpTrain = FourUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, SeventeenUp,random_state=4)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
SeventeenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=4) 
SeventeenUpforest.fit(X_train, y_train) 
SeventeenUpAccuracy = SeventeenUpforest.score(X_test, y_test)
SeventeenUpTrain = SeventeenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyUp,random_state=5)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=5) 
TwentyUpforest.fit(X_train, y_train) 
TwentyUpAccuracy = TwentyUpforest.score(X_test, y_test)
TwentyUpTrain = TwentyUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyThreeUp,random_state=6)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyThreeUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=6) 
TwentyThreeUpforest.fit(X_train, y_train) 
TwentyThreeUpAccuracy = TwentyThreeUpforest.score(X_test, y_test)
TwentyThreeUpTrain= TwentyThreeUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentySixUp,random_state=7)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentySixUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=7) 
TwentySixUpforest.fit(X_train, y_train)
TwentySixUpAccuracy = TwentySixUpforest.score(X_test, y_test)
TwentySixUpTrain = TwentySixUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyNineUp,random_state=8)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyNineUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=8) 
TwentyNineUpforest.fit(X_train, y_train)
TwentyNineUpAccuracy = TwentyNineUpforest.score(X_test, y_test)
TwentyNineUpTrain = TwentyNineUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyTwoUp,random_state=9)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyTwoUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=9) 
ThirtyTwoUpforest.fit(X_train, y_train)
ThirtyTwoUpAccuracy = ThirtyTwoUpforest.score(X_test, y_test)
ThirtyTwoUpTrain = ThirtyTwoUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyFiveUp,random_state=10)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyFiveUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=10) 
ThirtyFiveUpforest.fit(X_train, y_train)
ThirtyFiveUpAccuracy = ThirtyFiveUpforest.score(X_test, y_test)
ThirtyFiveUpTrain= ThirtyFiveUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyEightUp,random_state=12)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyEightUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=12) 
ThirtyEightUpforest.fit(X_train, y_train)
ThirtyEightUpAccuracy = ThirtyEightUpforest.score(X_test, y_test)
ThirtyEightUpTrain = ThirtyEightUpforest.score(X_train, y_train)
###############################################

# %%
X_train, X_test, y_train, y_test = train_test_split(X, OneDown,random_state=0)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
OneDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=0) 
OneDownforest.fit(X_train, y_train)
OneDownAccuracy = OneDownforest.score(X_test, y_test)
OneDownTrain = OneDownforest.score(X_train, y_train)
    #trainaccuracy.append(forest.score(X_train, y_train))
    #testaccuracy.append(forest.score(X_test, y_test))
X_train, X_test, y_train, y_test = train_test_split(X, TwoDown,random_state=1)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwoDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=1) 
TwoDownforest.fit(X_train, y_train)  
TwoDownAccuracy = TwoDownforest.score(X_test, y_test)
TwoDownTrain = TwoDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThreeDown,random_state=2)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThreeDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=2) 
ThreeDownforest.fit(X_train, y_train) 
ThreeDownAccuracy = ThreeDownforest.score(X_test, y_test)
ThreeDownTrain = ThreeDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FourDown,random_state=3)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FourDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=3) 
FourDownforest.fit(X_train, y_train) 
FourDownAccuracy = FourDownforest.score(X_test, y_test)
FourDownTrain= FourDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, SeventeenDown,random_state=4)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
SeventeenDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=4) 
SeventeenDownforest.fit(X_test, y_test) 
SeventeenDownAccuracy = SeventeenDownforest.score(X_test, y_test)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyDown,random_state=5)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=5) 
TwentyDownforest.fit(X_train, y_train) 
TwentyDownAccuracy = TwentyDownforest.score(X_test, y_test)
TwentyDownTrain = TwentyDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyThreeDown,random_state=6)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyThreeDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=6) 
TwentyThreeDownforest.fit(X_train, y_train)
TwentyThreeDownAccuracy = TwentyThreeDownforest.score(X_test, y_test)
TwentyThreeDownTrain = TwentyThreeDownforest.score(X_train, y_train)


X_train, X_test, y_train, y_test = train_test_split(X, TwentySixDown,random_state=7)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentySixDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=7) 
TwentySixDownforest.fit(X_train, y_train) 
TwentySixDownAccuracy = TwentySixDownforest.score(X_test, y_test)
TwentySixDownTrain = TwentySixDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyNineDown,random_state=8)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyNineDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=8) 
TwentyNineDownforest.fit(X_train, y_train)
TwentyNineDownAccuracy = TwentyNineDownforest.score(X_test, y_test)
TwentyNineDownTrain = TwentyNineDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyTwoDown,random_state=9)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyTwoDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=9) 
ThirtyTwoDownforest.fit(X_train, y_train)
ThirtyTwoDownAccuracy = ThirtyTwoDownforest.score(X_test, y_test)
ThirtyTwoDownTrain = ThirtyTwoDownforest.score(X_train, y_train)


X_train, X_test, y_train, y_test = train_test_split(X, ThirtyFiveDown,random_state=10)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyFiveDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=10) 
ThirtyFiveDownforest.fit(X_train, y_train)
ThirtyFiveDownAccuracy = ThirtyFiveDownforest.score(X_test, y_test)
ThirtyFiveDownTrain = ThirtyFiveDownforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyEightDown,random_state=12)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyEightDownforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=12) 
ThirtyEightDownforest.fit(X_train, y_train)
ThirtyEightDownAccuracy = ThirtyEightDownforest.score(X_test, y_test)
ThirtyEightDownTrain = ThirtyEightDownforest.score(X_train, y_train)
###############################################
###############################################

# %%
data = pd.read_excel('/Users/jpjansen/Desktop/12_13_Final_Data.xlsx',header = 0)
data = data.dropna()
np.set_printoptions(threshold=sys.maxsize)
Predictors = data.to_numpy() 
names = Predictors[:,0]
stonk_data = Predictors[:,1:]
print(stonk_data)

# %%
score = []
stonk_score = 0 
for i in range(len(stonk_data)):
    stonk = stonk_data[i].reshape(1, -1)
    
    OneUpprediction = OneUpforest.predict(stonk)
    if OneUpprediction[0] == 1:
        stonk_score = stonk_score+OneUpAccuracy
    elif OneUpprediction[0] == 0:
        stonk_score = stonk_score-OneUpAccuracy
        
    TwoUpprediction = TwoUpforest.predict(stonk)
    if TwoUpprediction[0] == 1:
        stonk_score = stonk_score+TwoUpAccuracy
    elif TwoUpprediction[0] == 0:
        stonk_score = stonk_score-TwoUpAccuracy
        
    ThreeUpprediction = ThreeUpforest.predict(stonk)
    if ThreeUpprediction[0] == 1:
        stonk_score = stonk_score+ThreeUpAccuracy
    elif ThreeUpprediction[0] == 0:
        stonk_score = stonk_score-ThreeUpAccuracy
        
    FourUpprediction = FourUpforest.predict(stonk)
    if FourUpprediction[0] == 1:
        stonk_score = stonk_score+FourUpAccuracy
    elif FourUpprediction[0] == 0:
        stonk_score = stonk_score-FourUpAccuracy
        
    SeventeenUpprediction = SeventeenUpforest.predict(stonk)
    if SeventeenUpprediction[0] == 1:
        stonk_score = stonk_score+SeventeenUpAccuracy
    elif SeventeenUpprediction[0] == 0:
        stonk_score = stonk_score-SeventeenUpAccuracy
            
    TwentyUpprediction = TwentyUpforest.predict(stonk)
    if TwentyUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyUpAccuracy
    elif TwentyUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyUpAccuracy
                    
    TwentyThreeUpprediction = TwentyThreeUpforest.predict(stonk)
    if TwentyThreeUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyThreeUpAccuracy
    elif TwentyThreeUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyThreeUpAccuracy
        
    TwentySixUpprediction = TwentySixUpforest.predict(stonk)
    if TwentySixUpprediction[0] == 1:
        stonk_score = stonk_score+TwentySixUpAccuracy
    elif TwentySixUpprediction[0] == 0:
        stonk_score = stonk_score-TwentySixUpAccuracy
        
        
##Begin modifying stock score with machine learning algorithms trained on max down data
    OneDownprediction = OneDownforest.predict(stonk)
    if OneDownprediction[0] == 0:
        stonk_score = stonk_score+OneDownAccuracy
    #elif OneDownprediction[0] == 1:
     #   stonk_score = stonk_score-(.5*OneDownAccuracy)
    TwoDownprediction = TwoDownforest.predict(stonk)
    if TwoDownprediction[0] == 0:
        stonk_score = stonk_score+TwoDownAccuracy
    #elif TwoDownprediction[0] == 1:
     #   stonk_score = stonk_score-(.5*TwoDownAccuracy)
        
    ThreeDownprediction = ThreeDownforest.predict(stonk)
    if ThreeDownprediction[0] == 0:
        stonk_score = stonk_score+ThreeDownAccuracy
    #elif ThreeDownprediction[0] == 1:
     #   stonk_score = stonk_score-(.5*ThreeDownAccuracy)
        
    FourDownprediction = FourDownforest.predict(stonk)
    if FourDownprediction[0] == 0:
        stonk_score = stonk_score+FourDownAccuracy
    #elif FourDownprediction[0] == 1:
        #stonk_score = stonk_score-(.5*FourDownAccuracy)
        
    SeventeenDownprediction = SeventeenDownforest.predict(stonk)
    if SeventeenDownprediction[0] == 1:
        stonk_score = stonk_score-SeventeenDownAccuracy
    elif SeventeenDownprediction[0] == 0:
        stonk_score = stonk_score+SeventeenDownAccuracy
            
    TwentyDownprediction = TwentyDownforest.predict(stonk)
    if TwentyDownprediction[0] == 1:
        stonk_score = stonk_score-TwentyDownAccuracy
    elif TwentyDownprediction[0] == 0:
        stonk_score = stonk_score+TwentyDownAccuracy
        
                
    TwentyThreeDownprediction = TwentyThreeDownforest.predict(stonk)
    if TwentyThreeDownprediction[0] == 1:
        stonk_score = stonk_score-TwentyThreeDownAccuracy
    elif TwentyThreeDownprediction[0] == 0:
        stonk_score = stonk_score+TwentyThreeDownAccuracy
        
    TwentySixDownprediction = TwentySixDownforest.predict(stonk)
    if TwentySixDownprediction[0] == 1:
        stonk_score = stonk_score-TwentySixDownAccuracy
    elif TwentySixDownprediction[0] == 0:
        stonk_score = stonk_score+TwentySixDownAccuracy
        
    max_score = 
    score.append(stonk_score/max_score)
    stonk_score = 0 
final_data = np.column_stack((names,score))
print(final_data)

# %%
final_data = final_data[final_data[:,1].argsort()]
print(final_data)
workbook  = xlsxwriter.Workbook('/Users/jpjansen/Documents/12_13_Predictions.xlsx')
############################################################################
worksheet = workbook.add_worksheet()
worksheet.write(0,0, 'stock')
worksheet.write(0,1, 'no over fitting factor prediction')
for i in range(len(final_data)):
    worksheet.write(i+1,0, final_data[i,0])
    worksheet.write(i+1,1, final_data[i,1])
workbook.close()
