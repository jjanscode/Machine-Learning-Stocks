# %%
from sklearn.tree.export import export_text
import pandas as pd
import numpy as np
import mglearn as mglearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
import sys
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
import xlsxwriter
#import all the stuff
# Out:
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
data = pd.read_excel('/Users/jpjansen/Documents/Last700MachineLearningSetV3.xlsx',header = 0)
data = data.dropna()
np.set_printoptions(threshold=sys.maxsize)
##read in data set

# %%
MachineLearning = data.to_numpy()

# %%
#X = MachineLearning[:,2:18] #specify my matrix of features for the machine learning 
X = MachineLearning[:,2:19] ###CHANGE
FortyOneUp= MachineLearning[:,-1]
ThirtyEightUp = MachineLearning[:,-2] 
ThirtyFiveUp = MachineLearning[:,-3]
ThirtyTwoUp = MachineLearning[:,-4]
TwentyNineUp = MachineLearning[:,-5]
TwentySixUp = MachineLearning[:,-6]
TwentyThreeUp = MachineLearning[:,-7]
TwentyTwoUp = MachineLearning[:,-8]
TwentyOneUp = MachineLearning[:,-9]
TwentyUp = MachineLearning[:,-10]
NineteenUp = MachineLearning[:,-11]
EighteenUp = MachineLearning[:,-12]
SeventeenUp = MachineLearning[:,-13]
SixteenUp = MachineLearning[:,-14]
FifteenUp = MachineLearning[:,-15]
FourteenUp = MachineLearning[:,-16]
ThirteenUp = MachineLearning[:,-17]
TwelveUp = MachineLearning[:,-18]
TenUp = MachineLearning[:,-19]
EightUp = MachineLearning[:,-20]
SixUp = MachineLearning[:,-21]
FiveUp = MachineLearning[:,-22]
FourUp = MachineLearning[:,-23]
ThreeUp = MachineLearning[:,-24]
TwoUp = MachineLearning[:,-25]
OneUp = MachineLearning[:,-26]
print(X)
# Out:
# [[43.55 9.46 68 1 33.25 6.137499999999996 0.7454739084132085
#   422832.9809725158 4228329.809725158 -161839.32346723042
#   113.0668295349679 4.56166772477107e-06 530.6666666666667
#   -84.23333333333332 4.07 -0.15 0.3347855227882038]
#  [21.87 1.21 69 1 8.78 -5.235000000000001 -0.9819967266775786
#   51239.669421487604 2094214.876033058 -144628.09917355372
#   309.69594045492215 4.723370728664705e-06 61.54873164218958
#   -83.86666666666667 4.07 -0.15 0.3347855227882038]
#  [140.65 10.65 74 1 13.78 -3.950000000000001 0.0 93896.71361502347
#   9295774.647887323 -105633.8028169014 68.00354269642874
#   4.842106364810249e-06 187.06199460916443 -59.65909090909091 4.07 -0.15
#   0.3347855227882038]
#  [16.03 2.43 76 1 28.57 -1.262500000000003 -0.0822368421052541
#   37860.082304526746 851028.806584362 -135390.9465020576
#   102.57495533185165 1.0641094406355714e-05 147.9591836734694
#   -68.64516129032259 4.07 -0.15 0.3347855227882038]
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, OneUp,random_state=0)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
OneUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=0) 
OneUpforest.fit(X_train, y_train)
OneUpAccuracy = OneUpforest.score(X_test, y_test)
OneUpTrain = OneUpforest.score(X_train, y_train)
    #trainaccuracy.append(forest.score(X_train, y_train))
    #testaccuracy.append(forest.score(X_test, y_test))
X_train, X_test, y_train, y_test = train_test_split(X, TwoUp,random_state=1)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwoUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=1) 
TwoUpforest.fit(X_train, y_train)  
TwoUpAccuracy = TwoUpforest.score(X_test, y_test)
TwoUpTrain = TwoUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThreeUp,random_state=2)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThreeUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=2) 
ThreeUpforest.fit(X_train, y_train) 
ThreeUpAccuracy = ThreeUpforest.score(X_test, y_test)
ThreeUpTrain= ThreeUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FourUp,random_state=3)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FourUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=3) 
FourUpforest.fit(X_train, y_train) 
FourUpAccuracy = FourUpforest.score(X_test, y_test)
FourUpTrain = FourUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FiveUp,random_state=3)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FiveUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=13) 
FiveUpforest.fit(X_train, y_train) 
FiveUpAccuracy = FiveUpforest.score(X_test, y_test)
FiveUpTrain = FiveUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FourteenUp,random_state=14)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FourteenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=14) 
FourteenUpforest.fit(X_train, y_train) 
FourteenUpAccuracy = FourteenUpforest.score(X_test, y_test)
FourteenUpTrain = FourteenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, FifteenUp,random_state=15)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
FifteenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=15) 
FifteenUpforest.fit(X_train, y_train) 
FifteenUpAccuracy = FifteenUpforest.score(X_test, y_test)
FifteenUpTrain = FifteenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, SixteenUp,random_state=16)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
SixteenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=16) 
SixteenUpforest.fit(X_train, y_train) 
SixteenUpAccuracy = SixteenUpforest.score(X_test, y_test)
SixteenUpTrain = SixteenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, SeventeenUp,random_state=17)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
SeventeenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=17) 
SeventeenUpforest.fit(X_train, y_train) 
SeventeenUpAccuracy = SeventeenUpforest.score(X_test, y_test)
SeventeenUpTrain = SeventeenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, EighteenUp,random_state=18)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
EighteenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=18) 
EighteenUpforest.fit(X_train, y_train) 
EighteenUpAccuracy = EighteenUpforest.score(X_test, y_test)
EighteenUpTrain = EighteenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, NineteenUp,random_state=18)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
NineteenUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=18) 
NineteenUpforest.fit(X_train, y_train) 
NineteenUpAccuracy = NineteenUpforest.score(X_test, y_test)
NineteenUpTrain = NineteenUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyUp,random_state=5)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=5) 
TwentyUpforest.fit(X_train, y_train) 
TwentyUpAccuracy = TwentyUpforest.score(X_test, y_test)
TwentyUpTrain = TwentyUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyOneUp,random_state=5)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyOneUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=5) 
TwentyOneUpforest.fit(X_train, y_train) 
TwentyOneUpAccuracy = TwentyOneUpforest.score(X_test, y_test)
TwentyOneUpTrain = TwentyOneUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyTwoUp,random_state=5)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyTwoUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=5) 
TwentyTwoUpforest.fit(X_train, y_train) 
TwentyTwoUpAccuracy = TwentyTwoUpforest.score(X_test, y_test)
TwentyTwoUpTrain = TwentyTwoUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyThreeUp,random_state=6)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyThreeUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=6) 
TwentyThreeUpforest.fit(X_train, y_train) 
TwentyThreeUpAccuracy = TwentyThreeUpforest.score(X_test, y_test)
TwentyThreeUpTrain= TwentyThreeUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentySixUp,random_state=7)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentySixUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=7) 
TwentySixUpforest.fit(X_train, y_train)
TwentySixUpAccuracy = TwentySixUpforest.score(X_test, y_test)
TwentySixUpTrain = TwentySixUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, TwentyNineUp,random_state=8)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
TwentyNineUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=8) 
TwentyNineUpforest.fit(X_train, y_train)
TwentyNineUpAccuracy = TwentyNineUpforest.score(X_test, y_test)
TwentyNineUpTrain = TwentyNineUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyTwoUp,random_state=9)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyTwoUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=9) 
ThirtyTwoUpforest.fit(X_train, y_train)
ThirtyTwoUpAccuracy = ThirtyTwoUpforest.score(X_test, y_test)
ThirtyTwoUpTrain = ThirtyTwoUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyFiveUp,random_state=10)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyFiveUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=10) 
ThirtyFiveUpforest.fit(X_train, y_train)
ThirtyFiveUpAccuracy = ThirtyFiveUpforest.score(X_test, y_test)
ThirtyFiveUpTrain= ThirtyFiveUpforest.score(X_train, y_train)

X_train, X_test, y_train, y_test = train_test_split(X, ThirtyEightUp,random_state=12)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
ThirtyEightUpforest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =80, random_state=12) 
ThirtyEightUpforest.fit(X_train, y_train)
ThirtyEightUpAccuracy = ThirtyEightUpforest.score(X_test, y_test)
ThirtyEightUpTrain = ThirtyEightUpforest.score(X_train, y_train)
###############################################

# %%
data = pd.read_excel('/Users/jpjansen/Desktop/5_9_Final_Data_Double.xlsx',header = 0)
#data = data.dropna()
np.set_printoptions(threshold=sys.maxsize)
Predictors = data.to_numpy() 
names = Predictors[:,0]
stonk_data = Predictors[:,1:]
print(stonk_data)
# Out:
# [[104.3 1.26 5 7 10.89 -3.818000000000001 -0.31645569620253194
#   -180158.73015873015 1089682.5396825396 -566666.6666666666
#   29.219196286945227 4.69494346036689e-05 12.000000000000002
#   -85.71428571428572 5.08 -0.45 0.3174167581412368]
#  [19.53 2.6 7 3 30.09 1.038 1.3645224171540018 52307.692307692305
#   322307.6923076923 11538.461538461537 19.56164508448558
#   3.2049283362926545e-05 15.044247787610635 -59.375 5.08 -0.45
#   0.3174167581412368]
#  [21.39 31.99 11 3 14.52 -2.620000000000001 1147.1734892787524
#   41919.349796811504 240668.95904970303 -8877.774304470147
#   234.3033399446468 2.5940950683087448e-05 252.31277533039642
#   -0.342679127725866 5.08 -0.45 0.3174167581412368]
#  [1.51 18.6 16 2 25.56 -2.827999999999999 3.104212860310434
#   -1720430.1075268816 28279569.892473117 -648709.6774193548
#   1343.9793962813565 2.7520184095815877e-08 1560.7142857142856
#   -32.90043290043289 5.08 -0.45 0.3755945847054519]
# ...

# %%
score = []
score_d = [] 
score_e = [] 
stonk_score = 0
stonk_score_d = 0
stonk_score_e = 0 
for i in range(len(stonk_data)):
    stonk = stonk_data[i].reshape(1, -1)
    
    OneUpprediction = OneUpforest.predict(stonk)
    if OneUpprediction[0] == 1:
        stonk_score = stonk_score+OneUpAccuracy
        stonk_score_d = stonk_score_d+OneUpAccuracy
    elif OneUpprediction[0] == 0:
        stonk_score = stonk_score-OneUpAccuracy
        
    TwoUpprediction = TwoUpforest.predict(stonk)
    if TwoUpprediction[0] == 1:
        stonk_score = stonk_score+TwoUpAccuracy
        stonk_score_d = stonk_score_d+TwoUpAccuracy
    elif TwoUpprediction[0] == 0:
        stonk_score = stonk_score-TwoUpAccuracy
        
    ThreeUpprediction = ThreeUpforest.predict(stonk)
    if ThreeUpprediction[0] == 1:
        stonk_score = stonk_score+ThreeUpAccuracy
        stonk_score_d = stonk_score_d+ThreeUpAccuracy
    elif ThreeUpprediction[0] == 0:
        stonk_score = stonk_score-ThreeUpAccuracy
        
    FourUpprediction = FourUpforest.predict(stonk)
    if FourUpprediction[0] == 1:
        stonk_score = stonk_score+FourUpAccuracy
        stonk_score_d = stonk_score_d+FourUpAccuracy
    elif FourUpprediction[0] == 0:
        stonk_score = stonk_score-FourUpAccuracy
        
    FiveUpprediction = FiveUpforest.predict(stonk)
    if FiveUpprediction[0] == 1:
        stonk_score = stonk_score+FiveUpAccuracy
        stonk_score_d = stonk_score_d+FiveUpAccuracy
    elif FourUpprediction[0] == 0:
        stonk_score = stonk_score-FiveUpAccuracy
        
    FourteenUpprediction = FourteenUpforest.predict(stonk)
    if FourteenUpprediction[0] == 1:
        stonk_score = stonk_score+FourteenUpAccuracy
        stonk_score_d = stonk_score_d+FourteenUpAccuracy
    elif FourUpprediction[0] == 0:
        stonk_score = stonk_score-FourteenUpAccuracy
        
    FifteenUpprediction = FifteenUpforest.predict(stonk)
    if FifteenUpprediction[0] == 1:
        stonk_score = stonk_score+FifteenUpAccuracy
        stonk_score_d = stonk_score_d+FifteenUpAccuracy
    elif FifteenUpprediction[0] == 0:
        stonk_score = stonk_score-FifteenUpAccuracy
        
    SixteenUpprediction = SixteenUpforest.predict(stonk)
    if SixteenUpprediction[0] == 1:
        stonk_score = stonk_score+SixteenUpAccuracy
        stonk_score_d = stonk_score_d+SixteenUpAccuracy
    elif FifteenUpprediction[0] == 0:
        stonk_score = stonk_score-SixteenUpAccuracy
        
    SeventeenUpprediction = SeventeenUpforest.predict(stonk)
    if SeventeenUpprediction[0] == 1:
        stonk_score = stonk_score+SeventeenUpAccuracy
        stonk_score_d = stonk_score_d+SeventeenUpAccuracy
    elif SeventeenUpprediction[0] == 0:
        stonk_score = stonk_score-SeventeenUpAccuracy
        
    EighteenUpprediction = EighteenUpforest.predict(stonk)
    if EighteenUpprediction[0] == 1:
        stonk_score = stonk_score+EighteenUpAccuracy
        stonk_score_d = stonk_score_d+EighteenUpAccuracy
    elif EighteenUpprediction[0] == 0:
        stonk_score = stonk_score-EighteenUpAccuracy
        
    NineteenUpprediction = NineteenUpforest.predict(stonk)
    if NineteenUpprediction[0] == 1:
        stonk_score = stonk_score+NineteenUpAccuracy
        stonk_score_d = stonk_score_d+NineteenUpAccuracy
    elif NineteenUpprediction[0] == 0:
        stonk_score = stonk_score-NineteenUpAccuracy
            
    TwentyUpprediction = TwentyUpforest.predict(stonk)
    if TwentyUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyUpAccuracy
        stonk_score_d = stonk_score_d+TwentyUpAccuracy
    elif TwentyUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyUpAccuracy
    
    TwentyOneUpprediction = TwentyOneUpforest.predict(stonk)
    if TwentyOneUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyOneUpAccuracy
        stonk_score_d = stonk_score_d+TwentyOneUpAccuracy
    elif TwentyOneUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyOneUpAccuracy
    
    TwentyTwoUpprediction = TwentyTwoUpforest.predict(stonk)
    if TwentyTwoUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyTwoUpAccuracy
        stonk_score_d = stonk_score_d+TwentyTwoUpAccuracy
    elif TwentyTwoUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyTwoUpAccuracy
                    
    TwentyThreeUpprediction = TwentyThreeUpforest.predict(stonk)
    if TwentyThreeUpprediction[0] == 1:
        stonk_score = stonk_score+TwentyThreeUpAccuracy
        stonk_score_d = stonk_score_d+TwentyThreeUpAccuracy
    elif TwentyThreeUpprediction[0] == 0:
        stonk_score = stonk_score-TwentyThreeUpAccuracy
        
    TwentySixUpprediction = TwentySixUpforest.predict(stonk)
    if TwentySixUpprediction[0] == 1:
        stonk_score = stonk_score+TwentySixUpAccuracy
        stonk_score_d = stonk_score_d+TwentySixUpAccuracy
    elif TwentySixUpprediction[0] == 0:
        stonk_score = stonk_score-TwentySixUpAccuracy
        
        

        
    #max_score = 
    max_score_d = 
    #max_score_e = OneDownAccuracy+TwoDownAccuracy+ThreeDownAccuracy+FourDownAccuracy+TwentyDownAccuracy+TwentyThreeDownAccuracy+TwentySixDownAccuracy
    #score.append(stonk_score/max_score)
    #score_e.append(stonk_score_e/max_score_e)
    score_d.append(stonk_score_d/max_score_d)
    stonk_score = 0 
    stonk_score_d = 0 
    stonk_score_e=0
unsorted_final_data = np.column_stack((names,score_d))
names_d = np.column_stack((names,score_d))
print('score d',names_d)
# Out:
# score d [['XSPA' 0.18260473588342435]
#  ['RKDA' 0.06739526411657558]
#  ['ETH' 0.13114754098360654]
#  ['RHE' 0.36065573770491793]
#  ['CCXI' 0.29735883424408005]
#  ['BBIG' 0.12887067395264115]
#  ['OBLN' 0.12887067395264115]
#  ['APOP' 0.0]
#  ['PRFX' 0.1926229508196721]
#  ['YTEN' 0.1926229508196721]
#  ['BGFV' 0.36065573770491793]
#  ['VISL' 0.24590163934426224]
#  ['CDEV' 0.29735883424408005]
#  ['ANY' 0.24590163934426224]
#  ['FTOC' 0.1926229508196721]
#  ['CLOV' 0.13114754098360654]
#  ['PRPO' 0.29735883424408005]
#  ['BTX' 0.29735883424408005]
#  ['BCRX' 0.29735883424408005]
#  ['MGI' 0.29735883424408005]
#  ['NKLA' 0.29735883424408005]
#  ['LEDS' 0.36065573770491793]
#  ['PLTR' 0.13114754098360654]
#  ['MVIS' 0.29735883424408005]
#  ['OCGN' 0.36065573770491793]
#  ['CREG' 0.29735883424408005]
#  ['SEAC' 0.0]
#  ['ADVM' 0.29735883424408005]
#  ['SONN' 0.29735883424408005]
#  ['CCIV' 0.1926229508196721]]

# %%
##DOUBLE CHECK EXPORTING CORRECTLY
export = np.column_stack((unsorted_final_data,score_d))

#export = np.column_stack((unsorted_final_data,final_data_b[:,1],final_data_c[:,1],score_d,score_e))

#export = np.column_stack((export,perf_data[:,2]))
#export = np.column_stack((export,final_data_b))
#export = np.column_stack((export,final_data_c))
#export = export[export[:,1].argsort()]
print(export)
workbook  = xlsxwriter.Workbook('/Users/jpjansen/Documents/5_9_DoubleMachineLearningPredictions.xlsx')
############################################################################
#scoring system a: dont penalize for max down above 1,2,3,4 other than that add/subtract full pts for being above/below
#each threshold 
#scoring system b: overfitting factor, dont penalize if max down predicted greater than 1,2, or 3, other wise add
#and subtract full pts for being above/below each threshold
#scoring system c: add half points for maxup above 1-4, max down below 17-26, subtract half points for max down above
#1-4 and max up below 17-26, add full pts for max up above 17-26, max down below 1-4, subtract full pts for max up 
#below 1-4, max down above 17-26 
#scoring system d: add points when ML predicts stock max up will be above classifier
#scoring system e: add points when ML predicts stock max down will be below classifier
worksheet = workbook.add_worksheet()
worksheet.write(0,0, 'stock')
worksheet.write(0,1, 'Scoring System A Percentile')
worksheet.write(0,2, 'Scoring System D Percentile')


for i in range(len(export)):
    worksheet.write(i+1,0, export[i,0])
    worksheet.write(i+1,1, export[i,1])
    worksheet.write(i+1,2, export[i,2])

chart1 = workbook.add_chart({'type': 'scatter'})
chart1.add_series({
    'name':       'Max Up',
    'categories': ['Sheet1', 1, 1, len(export), 1],
    'values':     ['Sheet1', 1, 7, len(export), 7],
})
chart1.add_series({
    'name':       'Max Down',
    'categories': ['Sheet1', 1, 1, len(export), 1],
    'values':     ['Sheet1', 1, 8, len(export), 8],
})
# Add a chart title and some axis labels.
chart1.set_title ({'name': 'Scoring System A'})
chart1.set_x_axis({'name': 'Percentile'})
chart1.set_y_axis({'name': 'Max Percent up/Down'})
# Set an Excel chart style.
chart1.set_style(11)
# Insert the chart into the worksheet (with an offset).
worksheet.insert_chart('J2', chart1, {'x_offset': 25, 'y_offset': 10})


chart2 = workbook.add_chart({'type': 'scatter'})
chart2.add_series({
    'name':       'Max Up',
    'categories': ['Sheet1', 1, 2, len(export), 2],
    'values':     ['Sheet1', 1, 7, len(export), 7],
})
chart2.add_series({
    'name':       'Max Down',
    'categories': ['Sheet1', 1, 2, len(export), 2], #start row, column, end row, column 
    'values':     ['Sheet1', 1, 8, len(export), 8],
})
# Add a chart title and some axis labels.
chart2.set_title ({'name': 'Scoring System D'})
chart2.set_x_axis({'name': 'Percentile'})
chart2.set_y_axis({'name': 'Max Percent up/Down'})
# Set an Excel chart style.
chart2.set_style(11)
# Insert the chart into the worksheet (with an offset).
worksheet.insert_chart('J17', chart2)

workbook.close()
# Out:
# [['XSPA' 0.18260473588342435 0.18260473588342435]
#  ['RKDA' 0.06739526411657558 0.06739526411657558]
#  ['ETH' 0.13114754098360654 0.13114754098360654]
#  ['RHE' 0.36065573770491793 0.36065573770491793]
#  ['CCXI' 0.29735883424408005 0.29735883424408005]
#  ['BBIG' 0.12887067395264115 0.12887067395264115]
#  ['OBLN' 0.12887067395264115 0.12887067395264115]
#  ['APOP' 0.0 0.0]
#  ['PRFX' 0.1926229508196721 0.1926229508196721]
#  ['YTEN' 0.1926229508196721 0.1926229508196721]
#  ['BGFV' 0.36065573770491793 0.36065573770491793]
#  ['VISL' 0.24590163934426224 0.24590163934426224]
#  ['CDEV' 0.29735883424408005 0.29735883424408005]
#  ['ANY' 0.24590163934426224 0.24590163934426224]
#  ['FTOC' 0.1926229508196721 0.1926229508196721]
#  ['CLOV' 0.13114754098360654 0.13114754098360654]
#  ['PRPO' 0.29735883424408005 0.29735883424408005]
#  ['BTX' 0.29735883424408005 0.29735883424408005]
#  ['BCRX' 0.29735883424408005 0.29735883424408005]
#  ['MGI' 0.29735883424408005 0.29735883424408005]
# ...

# %%
print(unsorted_final_data)

# %%
print(export[export[:,4].argsort()])
# Out:
# [['SNDL' -0.2721593127684499 -0.2529936086125253 -0.294543396211048
#   0.3730098559514784 0.14895330112721417 7.482993197278919
#   12.92517006802721]
#  ['MOTS' 0.18078875439281536 0.21139156054511066 0.1904673511204441
#   0.3980288097043215 0.5893719806763285 13.63636363636363
#   3.636363636363639]
#  ['BB' 0.18078875439281536 0.21139156054511066 0.1904673511204441
#   0.3980288097043215 0.5893719806763285 31.40495867768596
#   2.479338842975209]
#  ['DXC' 0.29793049590003906 0.2964145924803293 0.2754903830556628
#   0.5117513267626991 0.5893719806763285 10.07751937984495
#   24.03100775193799]
#  ['KODK' 0.29793049590003906 0.2964145924803293 0.2754903830556628
#   0.5117513267626991 0.5893719806763285 8.791208791208799
#   4.517704517704509]
#  ['LGHL' 0.013666536509176104 0.03680358683280517 0.015879377408138617
#   0.5117513267626991 0.2962962962962963 29.72144846796658
#   5.849582172701949]
#  ['METX' 0.29793049590003906 0.2964145924803293 0.2754903830556628
# ...

# %%
score_cutoff = 0 
sell_cutoff = 0 
for i in range(len(export)):
    if export[i,4]<.6:
        continue
    else:
        score_cutoff+=1
        print(export[i,0],export[i,4],export[i,-2])
        if export[i,-2]> 8:
            sell_cutoff+=1
print(sell_cutoff/score_cutoff)
# Out:
# JAGX 0.37368215540804367 9.090909090909092
# MARA 0.5072237407262787 34.60000000000001
# NXTD 0.39164388910581804 8.391608391608399
# IPDN 0.3814916048418587 17.74891774891775
# RIOT 0.6501366653650917 39.42857142857143
# ACST 0.41194845763373683 28.0597014925373
# DGLY 0.41194845763373683 23.38403041825096
# WWR 0.5322139789144866 12.07920792079208
# DPW 0.41194845763373683 55.60975609756099
# RHE 0.41194845763373683 49.27536231884059
# FTFT 0.6501366653650917 50.52631578947368
# WATT 0.41194845763373683 6.217616580310875
# BGI 0.5119094103865677 3.809523809523813
# APDN 0.39789144865287 32.12851405622489
# CNET 0.36274892620070276 18.18181818181818
# BNGO 0.4158531823506444 34.24620754463686
# 0.875

# %%
score_cutoff = 0 
sell_cutoff = 0 
for i in range(len(export)):
    if export[i,4]<.6:
        continue
    else:
        score_cutoff+=1
        print(export[i,0],export[i,4],export[i,-2])
        if export[i,-2]> 8:
            sell_cutoff+=1
print(sell_cutoff/score_cutoff)
# Out:
# LMFA 1.0 11.11111111111111
# JAGX 1.0 9.090909090909092
# AVGR 0.7490523123578469 76.80074836295603
# MARA 1.0 34.60000000000001
# NXTD 0.7490523123578469 8.391608391608399
# IPDN 0.7391963608794542 17.74891774891775
# RIOT 1.0 39.42857142857143
# ACST 0.6224412433661866 28.0597014925373
# DGLY 0.6224412433661866 23.38403041825096
# WWR 0.7391963608794542 12.07920792079208
# DPW 0.6224412433661866 55.60975609756099
# RHE 0.6224412433661866 49.27536231884059
# FTFT 1.0 50.52631578947368
# WATT 0.6224412433661866 6.217616580310875
# BGI 0.8658074298711145 3.809523809523813
# NVFY 0.6285064442759667 38.53606027987083
# APDN 0.755117513267627 32.12851405622489
# CNET 1.0 18.18181818181818
# NAKD 0.6224412433661866 60.20236087689714
# BNGO 0.772554965883245 34.24620754463686
# 0.9

# %%
average = np.asarray(np.column_stack((unsorted_final_data[:,1],final_data_b[:,1],final_data_c[:,1],score_d,score_e)))

# %%
print(average)
averages = np.mean(average, axis =1)
print(averages)
# Out:
# [[0.15850986121256397 0.16415543219666925 0.13653185302669835
#   0.5174129353233831 0.4387678437265214]
#  [0.30387143900657426 0.31271477663230235 0.28509119746233147
#   0.5174129353233831 0.5882794891059354]
#  [0.4083272461650842 0.41395717684377475 0.2985725614591594
#   0.8912579957356077 0.3005259203606311]
#  [0.1753104455807159 0.1979910124240021 0.17036743325403114
#   0.5174129353233831 0.45604808414725767]
#  [0.30387143900657426 0.31271477663230235 0.28509119746233147
#   0.5174129353233831 0.5882794891059354]
#  [0.42585829072315573 0.41448585778482677 0.3614195083267248
#   0.6361051883439943 0.5882794891059354]
#  [0.30387143900657426 0.31271477663230235 0.28509119746233147
#   0.5174129353233831 0.5882794891059354]
#  [0.6880934989043098 0.6637589214908802 0.5483743061062648
#   0.8912579957356077 0.5882794891059354]
#  [0.6880934989043098 0.6637589214908802 0.5483743061062648
#   0.8912579957356077 0.5882794891059354]
# ...
