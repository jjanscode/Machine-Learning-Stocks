# %%
from sklearn.tree.export import export_text
import pandas as pd
import numpy as np
import mglearn as mglearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
import sys
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
#import all the stuff
# Out:
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /Users/jpjansen/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
data = pd.read_excel('/Users/jpjansen/Documents/Machine Learning Set V2.xlsx',header = 0)
data = data.dropna()
np.set_printoptions(threshold=sys.maxsize)
##read in data set

# %%
MachineLearning = data.to_numpy()

# %%
X = MachineLearning[:,2:18] #specify my matrix of features for the machine learning 
FortyOneUp= MachineLearning[:,-1]
ThirtyEightUp = MachineLearning[:,-2] 
ThirtyFiveUp = MachineLearning[:,-3]
ThirtyTwoUp = MachineLearning[:,-4]
TwentyNineUp = MachineLearning[:,-5]
TwentySixUp = MachineLearning[:,-6]
TwentyThreeUp = MachineLearning[:,-7]
TwentyUp = MachineLearning[:,-8]
SeventeenUp = MachineLearning[:,-9]
FourteenUp = MachineLearning[:,-10]
TwelveUp = MachineLearning[:,-11]
TenUp = MachineLearning[:,-12]
EightUp = MachineLearning[:,-13]
SixUp = MachineLearning[:,-14]
FourUp = MachineLearning[:,-15]
ThreeUp = MachineLearning[:,-16]
TwoUp = MachineLearning[:,-17]
OneUp = MachineLearning[:,-18]
OneDown= MachineLearning[:,-19]
TwoDown= MachineLearning[:,-20]
ThreeDown= MachineLearning[:,-21]
FourDown=MachineLearning[:,-22]
SixDown= MachineLearning[:,-23]
EightDown= MachineLearning[:,-24]
TenDown= MachineLearning[:,-25]
TwelveDown= MachineLearning[:,-26]
FourteenDown= MachineLearning[:,-27]
SeventeenDown= MachineLearning[:,-28]
TwentyDown= MachineLearning[:,-29]
TwentyThreeDown= MachineLearning[:,-30]
TwentySixDown= MachineLearning[:,-31]
TwentyNineDown= MachineLearning[:,-32]
ThirtyTwoDown= MachineLearning[:,-33]
ThirtyFiveDown= MachineLearning[:,-34]
ThirtyEightDown= MachineLearning[:,-35]
FortyOneDown= MachineLearning[:,-36]
print(X)
# Out:
# [[19.9 1.04 2 10 29.52 -1.9179999999999993 -3.165735567970208
#   2210576.923076923 10970192.307692308 82692.30769230769
#   454.9019607843137 0.7797805642633229 195.2867688813174
#   -54.18502202643172 4.36 -1.32]
#  [85.49 1.43 6 8 32.89 -1.6980000000000004 1.4184397163120581
#   -312587.4125874126 1312587.4125874126 -343356.6433566434
#   9.222737819025523 26.883647798742135 472.0 -59.8314606741573 4.36 -1.32]
#  [32.93 2.22 8 7 18.64 -2.806000000000001 -0.44843049327353307
#   -290990.99099099095 4399099.099099099 -409009.009009009
#   156.672760511883 3.8424737456242704 334.4422700587084
#   -32.93051359516616 4.36 -1.32]
#  [8.8 1.29 10 7 31.87 5.047999999999998 28.31990450611757
#   2849612.403100775 24238759.68992248 145736.43410852712
#   2853.6363636363635 0.14017202930869704 126.31578947368422
#   -89.76190476190476 4.36 -1.32]
#  [66.7 0.8591 3 8 29.27 1.0500000000000007 -1.332261398874475
#   4514026.30659993 37772087.06786171 2847165.638458852 305.7562524811433
# ...

# %%
trainaccuracy = []
randomstate = []
testaccuracy = []
for i in range(2,100):
    
    X_train, X_test, y_train, y_test = train_test_split(X, FourDown,random_state=i) #split and randomize data
    y_train = y_train.astype(int)
    y_test = y_test.astype(int)
    forest = RandomForestClassifier(n_estimators= 100, max_features = 8, min_samples_split =15, random_state=i) 
    forest.fit(X_train, y_train)
    trainaccuracy.append(forest.score(X_train, y_train))
    testaccuracy.append(forest.score(X_test, y_test))
    randomstate.append(i)
plt.plot(randomstate, trainaccuracy, label = 'Train Accuracy')
plt.plot(randomstate,testaccuracy, label = 'Test Accuracy')
plt.legend()
plt.xlabel('Random Seed Number')
plt.ylabel('Accuracy')
plt.title('Four Percent Down Minimum Price Classifier Random Seed Sweep')
print("Test",np.median(testaccuracy))
print("Train",np.median(trainaccuracy))
print("Train STDEV",np.std(trainaccuracy))
print("Test STDEV",np.std(testaccuracy))
# Out:
# Test 0.7724719101123596
# Train 0.9360902255639098
# Train STDEV 0.007761132478275039
# Test STDEV 0.02889313830665613
